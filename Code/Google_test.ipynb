# %% [markdown]
# <a href="https://colab.research.google.com/github/VColby/ENEL-619-Final-Project/blob/main/Code/Google_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
y=2
z=x+y

print(z)
# Out:
# 5
